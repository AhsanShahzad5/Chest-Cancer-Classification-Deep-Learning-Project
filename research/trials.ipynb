# %% [markdown]
# ## Download data from gdrive
#
# We store data in google drive to avoid s3 bucket cost

# %%
import gdown

url = "https://drive.google.com/file/d/1N927NnbsuBOOBmK4VrTnA1Ya04QB1G3t/view?usp=sharing"

# %%
type(url)
# Out:
# str

# %%
url.split('/')
# Out:
# ['https:',
#  '',
#  'drive.google.com',
#  'file',
#  'd',
#  '1N927NnbsuBOOBmK4VrTnA1Ya04QB1G3t',
#  'view?usp=sharing']

# %%
gdown.download(url, "Chest-CT-Scan-data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1N927NnbsuBOOBmK4VrTnA1Ya04QB1G3t
# From (redirected): https://drive.google.com/uc?id=1N927NnbsuBOOBmK4VrTnA1Ya04QB1G3t&confirm=t&uuid=b11663fb-7991-4311-835f-6b9cfc50b260
# To: d:\Projects\1-Practice and Learning\0 - COMPLETE NEW LEARNING ML and DL\3-PROJECTS\Deep Learning Projects\Chest Cancer Classification End to End Project\research\Chest-CT-Scan-data.zip
# 100%|██████████| 80.5M/80.5M [01:17<00:00, 1.04MB/s]
# 'Chest-CT-Scan-data.zip'
